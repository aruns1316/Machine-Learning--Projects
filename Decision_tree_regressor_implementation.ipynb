# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()

# %%
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df = pd.DataFrame(data.data, columns= data.feature_names)
df["Price"] = data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# @title AveRooms

from matplotlib import pyplot as plt
df['AveRooms'].plot(kind='line', figsize=(8, 4), title='AveRooms')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# @title MedInc vs HouseAge

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='MedInc', y='HouseAge', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.shape
# Out:
# (20640, 9)

# %%
#taking 20 percent of the data for our case

df = df.sample(frac = 0.20)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 2008   1.8967      52.0  5.000000   1.049180       406.0  3.327869     36.74
# 10636  4.4286       6.0  4.203166   0.978892       832.0  2.195251     33.70
# 3795   2.4835      43.0  4.253731   1.058209      1510.0  2.253731     34.16
# 3418   3.7566      32.0  5.453390   1.125000      2609.0  5.527542     34.28
# 19151  1.6033      14.0  4.641791   1.101493       493.0  1.471642     38.35
# ...       ...       ...       ...        ...         ...       ...       ...
# 18134  5.5388      25.0  6.104536   1.013807      1251.0  2.467456     37.35
# 13031  4.6902      10.0  6.534570   1.126476      1632.0  2.752108     38.67
# 18966  2.5896      27.0  4.598930   1.052139      2085.0  2.787433     38.26
# 1742   2.5164      36.0  4.181298   1.013359      1563.0  2.982824     37.96
# 15189  4.3571      16.0  4.142857   0.952381        32.0  1.523810     33.03
#
#        Longitude  Price
# ...

# %%
df.shape
# Out:
# (4128, 9)

# %%
#independent and dependend features

X = df.iloc [:,:-1]
y = df.iloc [:,-1]

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 2008   1.8967      52.0  5.000000   1.049180       406.0  3.327869     36.74
# 10636  4.4286       6.0  4.203166   0.978892       832.0  2.195251     33.70
# 3795   2.4835      43.0  4.253731   1.058209      1510.0  2.253731     34.16
# 3418   3.7566      32.0  5.453390   1.125000      2609.0  5.527542     34.28
# 19151  1.6033      14.0  4.641791   1.101493       493.0  1.471642     38.35
# ...       ...       ...       ...        ...         ...       ...       ...
# 18134  5.5388      25.0  6.104536   1.013807      1251.0  2.467456     37.35
# 13031  4.6902      10.0  6.534570   1.126476      1632.0  2.752108     38.67
# 18966  2.5896      27.0  4.598930   1.052139      2085.0  2.787433     38.26
# 1742   2.5164      36.0  4.181298   1.013359      1563.0  2.982824     37.96
# 15189  4.3571      16.0  4.142857   0.952381        32.0  1.523810     33.03
#
#        Longitude
# 2008     -119.82
# ...

# %%
y
# Out:
# 2008     0.438
# 10636    2.395
# 3795     2.743
# 3418     1.467
# 19151    0.675
#          ...
# 18134    3.521
# 13031    1.710
# 18966    1.047
# 1742     1.142
# 15189    1.446
# Name: Price, Length: 4128, dtype: float64
